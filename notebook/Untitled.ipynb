# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carEval.csv')

# %%
# - Pré-processar os dados
# Definir a ordem das categorias para cada variável ordinal
ordinal_mapping = {
    'buying': ['low', 'med', 'high', 'vhigh'],
    'maint': ['low', 'med', 'high', 'vhigh'],
    'doors': ['2', '3', '4', '5more'],
    'persons': ['2', '4', 'more'],
    'lug_boot': ['small', 'med', 'big'],
    'safety': ['low', 'med', 'high']
}

# %%
# Aplicando a codificação ordinal
ordinal_encoder = OrdinalEncoder(categories=[ordinal_mapping[col] for col in df.columns[:-1]])
df[df.columns[:-1]] = ordinal_encoder.fit_transform(df[df.columns[:-1]])

# %%
class_order = ['unacc', 'acc', 'good', 'vgood']

# %%
# Codificando a variável target (class values) com LabelEncoder e a ordem definida
label_encoder = LabelEncoder()
label_encoder.fit(class_order)  # Ajustar o encoder à ordem das classes
df['class values'] = label_encoder.transform(df['class values'])

# %%
# - Separação das features(x) e targets(y) / Dividir os dados em treino e teste
X = df.drop('class values', axis=1)
y = df['class values']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# - Criar e treinar a árvore de decisão
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# - Avaliar o modelo
y_pred = clf.predict(X_test)

# %%
# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f'Acurácia: {accuracy:.2f}')
# Out:
# Acurácia: 0.97

# %%
# Relatório de classificação
print("\nRelatório de Classificação:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          acc       0.95      0.92      0.93       118
#         good       0.81      0.89      0.85        19
#        unacc       0.99      0.99      0.99       358
#        vgood       0.91      0.88      0.89        24
#
#     accuracy                           0.97       519
#    macro avg       0.91      0.92      0.92       519
# weighted avg       0.97      0.97      0.97       519

# %%
plt.figure(figsize=(160,80))
plot_tree(clf, filled=True, feature_names=X.columns, class_names=label_encoder.classes_, rounded=True)
plt.show()
